# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhakti77/pandas/blob/main/Working_with_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Working with JSON
import pandas as pd
json_df = pd.read_json("/orders_ETL.json")
json_df
# Out:
#     order_id  order_date  total_amount  \
# 0          1  2024-01-10         200.5
# 1          2  2024-01-12         150.0
# 2          3  2024-01-12         120.0
# 3          4  2024-01-13         300.5
# 4          5  2024-01-14         180.0
# 5          6  2024-01-14         250.0
# 6          7  2024-01-16         180.0
# 7          8  2024-01-16         230.0
# 8          9  2024-01-17         310.0
# 9         10  2024-01-18         130.0
# 10        11  2024-01-18         250.0
# 11        12  2024-01-19         180.0
#
#                                              customer  \
# 0   {'customer_id': 101, 'name': 'John Doe', 'emai...
# 1   {'customer_id': 102, 'name': 'Jane Smith', 'em...
# 2   {'customer_id': 103, 'name': 'Alice Johnson', ...
# 3   {'customer_id': 101, 'name': 'John Doe', 'emai...
# 4   {'customer_id': 104, 'name': 'Bob Brown', 'ema...
# 5   {'customer_id': 105, 'name': 'Sania', 'email':...
# 6   {'customer_id': 106, 'name': 'Rohit', 'email':...
# 7   {'customer_id': 107, 'name': 'Nina Patel', 'em...
# 8   {'customer_id': 108, 'name': 'Tom Harris', 'em...
# 9   {'customer_id': 109, 'name': 'Eva Lee', 'email...
# 10  {'customer_id': 101, 'name': 'John Doe', 'emai...
# 11  {'customer_id': 103, 'name': 'Alice Johnson', ...
#
#                                              products
# 0   [{'product_id': 'P01', 'name': 'Wireless Mouse...
# 1   [{'product_id': 'P03', 'name': 'Laptop Stand',...
# 2   [{'product_id': 'P04', 'name': 'Gaming Headset...
# 3   [{'product_id': 'P01', 'name': 'Wireless Mouse...
# 4   [{'product_id': 'P03', 'name': 'Laptop Stand',...
# 5   [{'product_id': 'P01', 'name': 'Wireless Mouse...
# 6   [{'product_id': 'P02', 'name': 'Bluetooth Keyb...
# 7   [{'product_id': 'P01', 'name': 'Wireless Mouse...
# 8   [{'product_id': 'P04', 'name': 'Gaming Headset...
# 9   [{'product_id': 'P05', 'name': 'Desk Organizer...
# 10  [{'product_id': 'P04', 'name': 'Gaming Headset...
# 11  [{'product_id': 'P01', 'name': 'Wireless Mouse...
