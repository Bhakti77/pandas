# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhakti77/pandas/blob/main/Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# series from list

# %%
ice_cream = ['mango','chocolate','vanilla','strawberry']
s = pd.Series(ice_cream)
print(s)
#index data
# Out:
# 0         mango
# 1     chocolate
# 2       vanilla
# 3    strawberry
# dtype: object

# %%
s.sum()
# Out:
# 'mangochocolatevanillastrawberry'

# %%
lottery_numbers=[2,4,5,223,54]
n = pd.Series(lottery_numbers)

# %%
n.sum()
# Out:
# np.int64(288)

# %% [markdown]
# series from dictionary

# %%
sushi = {'salmon':'orange','tuna':'red','eel':'brown'}
s = pd.Series(sushi)
print(s)
# Out:
# salmon    orange
# tuna         red
# eel        brown
# dtype: object

# %%
s.iloc[1]
# Out:
# 'red'

# %% [markdown]
# Series methods
#
# seriesobject.methodname()

# %%
prices = pd.Series([2.99,4.45,1.36])
prices
# Out:
# 0    2.99
# 1    4.45
# 2    1.36
# dtype: float64

# %%
print(prices.sum())
# Out:
# 8.8

# %%
print(prices.product())
# Out:
# 18.095480000000006

# %%
print(prices.mean())
# Out:
# 2.9333333333333336

# %%
print(prices.std())
# Out:
# 1.5457791994115246

# %% [markdown]
# Series attributes
#
# seriesobject.attribute

# %%
adjectives = pd.Series(['Smart','Handsome','Brilliant','Charming','Smart'])

# %%
adjectives.size
# Out:
# 5

# %%
adjectives.dtype
# Out:
# dtype('O')

# %%
adjectives.is_unique
# Out:
# False

# %%
adjectives.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
adjectives.shape
# Out:
# (5,)

# %% [markdown]
# Import series with pd.read_csv

# %% [markdown]
# head and tails methods

# %%
product = ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Charger',
            'Mouse', 'Keyboard', 'Monitor', 'Webcam', 'Speaker']
products = pd.Series(product, name='product')

# %%
products.head(3)
products.tail(2)
# Out:
# 8     Webcam
# 9    Speaker
# Name: product, dtype: object

# %% [markdown]
# Passing series to Pyhon built in functions

# %%
print(len(products))
print(type(products))
print(list(products))
print(sorted(products ))
print(max(products))
print(min(products))
# Out:
# 10
# <class 'pandas.core.series.Series'>
# ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Charger', 'Mouse', 'Keyboard', 'Monitor', 'Webcam', 'Speaker']
# ['Charger', 'Headphones', 'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Phone', 'Speaker', 'Tablet', 'Webcam']
# Webcam
# Charger

# %% [markdown]
# IN keyword

# %%
'Webcam' in products.values
# 'Bhakti' in products.values
# Out:
# True

# %%
sort_values/sort_index methods
# Out:
#   File "/tmp/ipykernel_2385/1371996094.py", line 1
#     sort_values/sort_index methods
#                            ^
# SyntaxError: invalid syntax

# %%
products.sort_values(ascending=False)

# %%
products.sort_index()

# %% [markdown]
# Extract series values by index position/index labels iloc and loc

# %%
products.iloc[0]

# %%
products.loc[0]

# %% [markdown]
# Get method

# %% [markdown]
# Overwrite a series value

# %% [markdown]
# copy on write and copy method

# %% [markdown]
# Math method on series

# %%
print(products.count()) #different than size pr len incase of missing values

# %%
print(products.sum())

# %% [markdown]
# Broadcasting - adding same details to every element

# %%
products * 10
# Out:
# 0    LaptopLaptopLaptopLaptopLaptopLaptopLaptopLapt...
# 1    PhonePhonePhonePhonePhonePhonePhonePhonePhoneP...
# 2    TabletTabletTabletTabletTabletTabletTabletTabl...
# 3    HeadphonesHeadphonesHeadphonesHeadphonesHeadph...
# 4    ChargerChargerChargerChargerChargerChargerChar...
# 5    MouseMouseMouseMouseMouseMouseMouseMouseMouseM...
# 6    KeyboardKeyboardKeyboardKeyboardKeyboardKeyboa...
# 7    MonitorMonitorMonitorMonitorMonitorMonitorMoni...
# 8    WebcamWebcamWebcamWebcamWebcamWebcamWebcamWebc...
# 9    SpeakerSpeakerSpeakerSpeakerSpeakerSpeakerSpea...
# Name: product, dtype: object

# %% [markdown]
# value_counts()
# Counts how many times each unique value appears in a Series — one of the most used methods in real DA work.

# %%
products.value_counts()
# Out:
# product
# Laptop        1
# Phone         1
# Tablet        1
# Headphones    1
# Charger       1
# Mouse         1
# Keyboard      1
# Monitor       1
# Webcam        1
# Speaker       1
# Name: count, dtype: int64

# %% [markdown]
# apply method
