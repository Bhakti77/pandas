# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhakti77/pandas/blob/main/Pandas_Intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = {
    'order_id':   [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'customer':   ['Aarav', 'Priya', 'Rohan', 'Sneha', 'Karan',
                   'Nisha', 'Amit', 'Pooja', 'Vikram', 'Anjali'],
    'city':       ['Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Bangalore',
                   'Delhi', None, 'Mumbai', 'Bangalore', 'Delhi'],
    'category':   ['Electronics', 'Appliances', 'Electronics', 'Fitness',
                   'Electronics', 'Appliances', 'Fitness', 'Electronics',
                   None, 'Appliances'],
    'amount':     [75000, 3500, 82000, 1200, 45000,
                   None, 6000, 45000, 3200, 12000],
    'status':     ['delivered', 'delivered', 'pending', None, 'cancelled',
                   'delivered', 'pending', 'delivered', 'cancelled', 'delivered']
}

df = pd.DataFrame(data)
df
# Out:
#    order_id customer       city     category   amount     status
# 0       101    Aarav     Mumbai  Electronics  75000.0  delivered
# 1       102    Priya       Pune   Appliances   3500.0  delivered
# 2       103    Rohan      Delhi  Electronics  82000.0    pending
# 3       104    Sneha     Mumbai      Fitness   1200.0       None
# 4       105    Karan  Bangalore  Electronics  45000.0  cancelled
# 5       106    Nisha      Delhi   Appliances      NaN  delivered
# 6       107     Amit       None      Fitness   6000.0    pending
# 7       108    Pooja     Mumbai  Electronics  45000.0  delivered
# 8       109   Vikram  Bangalore         None   3200.0  cancelled
# 9       110   Anjali      Delhi   Appliances  12000.0  delivered

# %%
df.isnull().sum()
# Out:
# order_id    0
# customer    0
# city        1
# category    1
# amount      1
# status      1
# dtype: int64

# %%
#agg - multiple aggregation same time

df.groupby('city')['amount'].agg(
    total_sales = 'sum',
    avg_sales = 'mean',
    max_sales = 'max'
)
# Out:
#            total_sales  avg_sales  max_sales
# city
# Bangalore      48200.0    24100.0    45000.0
# Delhi          94000.0    47000.0    82000.0
# Mumbai        121200.0    40400.0    75000.0
# Pune            3500.0     3500.0     3500.0

# %%
#multiple column in agg - amount and order_id
df.groupby('city').agg(
    total_amount  = ('amount', 'sum'),
    avg_amount    = ('amount', 'mean'),
    order_count   = ('order_id', 'count')
)
# Out:
#            total_amount  avg_amount  order_count
# city
# Bangalore       48200.0     24100.0            2
# Delhi           94000.0     47000.0            3
# Mumbai         121200.0     40400.0            3
# Pune             3500.0      3500.0            1

# %%
#transform
df['city_total'] = df.groupby('city')['amount'].transform('sum')
df[['customer', 'city', 'amount', 'city_total']]
# Out:
#   customer       city   amount  city_total
# 0    Aarav     Mumbai  75000.0    121200.0
# 1    Priya       Pune   3500.0      3500.0
# 2    Rohan      Delhi  82000.0     94000.0
# 3    Sneha     Mumbai   1200.0    121200.0
# 4    Karan  Bangalore  45000.0     48200.0
# 5    Nisha      Delhi      NaN     94000.0
# 6     Amit       None   6000.0         NaN
# 7    Pooja     Mumbai  45000.0    121200.0
# 8   Vikram  Bangalore   3200.0     48200.0
# 9   Anjali      Delhi  12000.0     94000.0

# %%
df['category_total'] = df.groupby('category')['amount'].transform('sum')
df['pct_of_category'] = df['amount'] / df['category_total'] * 100
df[['customer', 'category', 'amount', 'category_total', 'pct_of_category']]
# Out:
#   customer     category   amount  category_total  pct_of_category
# 0    Aarav  Electronics  75000.0        247000.0        30.364372
# 1    Priya   Appliances   3500.0         15500.0        22.580645
# 2    Rohan  Electronics  82000.0        247000.0        33.198381
# 3    Sneha      Fitness   1200.0          7200.0        16.666667
# 4    Karan  Electronics  45000.0        247000.0        18.218623
# 5    Nisha   Appliances      NaN         15500.0              NaN
# 6     Amit      Fitness   6000.0          7200.0        83.333333
# 7    Pooja  Electronics  45000.0        247000.0        18.218623
# 8   Vikram         None   3200.0             NaN              NaN
# 9   Anjali   Appliances  12000.0         15500.0        77.419355

# %%
df['pct_of_category'] = df['amount'] / df['city_total'] * 100
df[['customer', 'city', 'amount', 'city_total', 'pct_of_city']]

# %%
#Handling duplicates
import pandas as pd
import numpy as np

data = {
    'order_id':   [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'customer':   ['Aarav', 'Priya', 'Rohan', 'Sneha', 'Karan',
                   'Nisha', 'Amit', 'Pooja', 'Vikram', 'Anjali'],
    'city':       ['Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Bangalore',
                   'Delhi', None, 'Mumbai', 'Bangalore', 'Delhi'],
    'category':   ['Electronics', 'Appliances', 'Electronics', 'Fitness',
                   'Electronics', 'Appliances', 'Fitness', 'Electronics',
                   None, 'Appliances'],
    'amount':     [75000, 3500, 82000, 1200, 45000,
                   None, 6000, 45000, 3200, 12000],
    'status':     ['delivered', 'delivered', 'pending', None, 'cancelled',
                   'delivered', 'pending', 'delivered', 'cancelled', 'delivered']
}

df = pd.DataFrame(data)

# add duplicates
duplicate_rows = df.iloc[[0, 2]]
df = pd.concat([df, duplicate_rows], ignore_index=True)
df.shape
# Out:
# (12, 6)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool
